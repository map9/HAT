# %%
import docbook

# %%
# test Title
try:
  title1 = docbook.Title('')
except ValueError as e:
  print(f"1, docbook.Title(''), Failed to create object: {e}")

title2 = docbook.Title("钢铁是怎样炼成的", "苏联文学作品",  "红色的经典")
print(f"2, {title2}")

title3 = docbook.Title.from_array("钢铁是怎样炼成的", "",  "红色的经典")
print(f"3, {title3}")

title4 = docbook.Title.from_list(["钢铁是怎样炼成的", "红色的经典"])
print(f"4, {title4}")

title5 = docbook.Title.from_list(["钢铁是怎样炼成的"])
print(f"5, {title5}")

try:
  title6 = docbook.Title.from_list(["", "红色的经典"])
except ValueError as e:
  print(f"6, docbook.Title.from_list(['', '红色的经典']), Failed to create object: {e}")

title7 = docbook.Title.from_dict({
  'title': "钢铁是怎样炼成的",
  'prefix': "",
  'subtitle': ""
})
print(f"7, {title7}")

try:
  title8 = docbook.Title.from_dict({
    'title': "",
    'prefix': None,
    'subtitle': None
  })
except ValueError as e:
  print(f"8, docbook.Title.from_dict({{'title': '','prefix': None,'subtitle': None}}), Failed to create object: {e}")

title9 = docbook.Title.from_dict({
  'title': "钢铁是怎样炼成的"
})
print(f"9, {title9}")

try:
  title10 = docbook.Title.from_dict({})
except ValueError as e:
  print(f"10, docbook.Title.from_dict({{}}), Failed to create object: {e}")

title11 = docbook.Title.from_dict(None)
print(f"11, {title11}")
print(f"repr3, {repr(title3)}")

title9.title = "钢铁是怎样炼成的"
title9.subtitle = '这是一个副标题'
print(f"modify attrs, {title9}")
try:
  title9.title = ""
except ValueError as e:
  print(f"modify attrs: title9.title = '', Failed to create object: {e}")
print(f"read attrs, {title9.title}")
# Out:
# 1, docbook.Title(''), Failed to create object: Invalid Title.title Value
# 2, {"title": "钢铁是怎样炼成的", "prefix": "苏联文学作品", "subtitle": "红色的经典", "attrs": {}}
# 3, {"title": "钢铁是怎样炼成的", "prefix": "", "subtitle": "红色的经典", "attrs": {}}
# 4, {"title": "钢铁是怎样炼成的", "prefix": "红色的经典", "subtitle": null, "attrs": {}}
# 5, {"title": "钢铁是怎样炼成的", "prefix": null, "subtitle": null, "attrs": {}}
# 6, docbook.Title.from_list(['', '红色的经典']), Failed to create object: Invalid Title Value
# 7, {"title": "钢铁是怎样炼成的", "prefix": "", "subtitle": "", "attrs": {}}
# 8, docbook.Title.from_dict({'title': '','prefix': None,'subtitle': None}), Failed to create object: Invalid Title Value
# 9, {"title": "钢铁是怎样炼成的", "prefix": null, "subtitle": null, "attrs": {}}
# 10, docbook.Title.from_dict({}), Failed to create object: Invalid Title Value
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 50
# ...

# %%
# test Dynasty
try:
  dynasty1 = docbook.Dynasty('')
except ValueError as e:
  print(f"1, docbook.Dynasty(''), Failed to create object: {e}")

dynasty2 = docbook.Dynasty('南宋')
print(f"2, {dynasty2}")

dynasty3 = docbook.Dynasty.from_dict({
  'value': '北齐'
})
print(f"3, {dynasty3}")

dynasty4 = docbook.Dynasty.from_dict({})
print(f"4, {dynasty4}")

try:
  dynasty3.value = ""
except ValueError as e:
  print(f"modify attrs: dynasty3.value = '元', Failed to create object: {e}")
dynasty3.value = "元"
print(f"modify attrs, {dynasty3.value}")
# Out:
# 1, {}
# 2, {"value": "南宋", "attrs": {}}
# 3, {"value": "北齐", "attrs": {}}
# 4, None
# modify attrs: dynasty3.value = '元', Failed to create object: Invalid Dynasty Value
# modify attrs, 元

# %%
# test Author
try:
  author1 = docbook.Author('')
except ValueError as e:
  print(f"1, docbook.Author(''), Failed to create object: {e}")

author2 = docbook.Author("胡三省")
print(f"2, {author2}")

try:
  author3 = docbook.Author("胡三省", '', '')
except ValueError as e:
  print(f"3, docbook.Author('胡三省', '', ''), Failed to create object: {e}")

author4 = docbook.Author("胡三省", dynasty='南宋', officialPosition='')
print(f"4, {author4}")

title5 = docbook.Author.from_array("胡三省", "辑注",  "南宋")
print(f"3, {title3}")

title4 = docbook.Title.from_list(["钢铁是怎样炼成的", "红色的经典"])
print(f"4, {title4}")
title5 = docbook.Title.from_list(["钢铁是怎样炼成的"])
print(f"5, {title5}")
title6 = docbook.Title.from_list(["", "红色的经典"])
print(f"6, {title6}")
title7 = docbook.Title.from_dict({
  'title': "钢铁是怎样炼成的",
  'prefix': "",
  'subtitle': ""
})
print(f"7, {title7}")
title8 = docbook.Title.from_dict({
  'title': "",
  'prefix': None,
  'subtitle': None
})
print(f"8, {title8}")
title9 = docbook.Title.from_dict({
  'title': "钢铁是怎样炼成的"
})
print(f"9, {title9}")
title10 = docbook.Title.from_dict({})
print(f"10, {title10}")
title11 = docbook.Title.from_dict(None)
print(f"11, {title11}")
print(f"repr3, {repr(title3)}")

title9.title = "钢铁是怎样炼成的"
title9.subtitle = '这是一个副标题'
print(f"modify attrs, {title9}")
try:
  title9.title = ""
except ValueError as e:
  print(f"modify attrs: title9.title = '', Failed to create object: {e}")
print(f"read attrs, {title9.title}")
